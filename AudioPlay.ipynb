# %% [markdown]
# <a href="https://colab.research.google.com/github/paoloros97/teoresi/blob/main/AudioPlay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Audio
fileaudio = '/content/drive/MyDrive/handel.wav'
wn = Audio(fileaudio, autoplay=True)

# %%
display(wn)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
